# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откройте-файлы-и-изучите-их" data-toc-modified-id="Откройте-файлы-и-изучите-их-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Откройте файлы и изучите их</a></span></li><li><span><a href="#Проверка-эффективности-обогащения" data-toc-modified-id="Проверка-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#обучающая-выборка-df_gold_recovery_train" data-toc-modified-id="обучающая-выборка-df_gold_recovery_train-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>обучающая выборка df_gold_recovery_train</a></span></li><li><span><a href="#тестовая-выборка-df_gold_recovery_test" data-toc-modified-id="тестовая-выборка-df_gold_recovery_test-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>тестовая выборка df_gold_recovery_test</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-Au,-Ag,-Pb" data-toc-modified-id="Изменение-концентрации-металлов-Au,-Ag,-Pb-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации металлов Au, Ag, Pb</a></span></li><li><span><a href="#Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Анализ-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-черновом-и-финальном-концентратах" data-toc-modified-id="Анализ-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-черновом-и-финальном-концентратах-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ суммарной концентрации всех веществ на разных стадиях: в сырье, черновом и финальном концентратах</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение моделей и оценка их качества</a></span></li><li><span><a href="#Выбор-лучшей-модели-и-проверка-на-тестовой-выборке" data-toc-modified-id="Выбор-лучшей-модели-и-проверка-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выбор лучшей модели и проверка на тестовой выборке</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Необходимо подготовить прототип модели машинного обучения для компании «Цифры». <br>
# Компания разрабатывает решения для эффективной работы промышленных предприятий.<br>
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. <br>
# В нашем распоряжении данные с параметрами добычи и очистки. <br>
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# **Шаги нашего исследования:**
# - подготовим данные
# - проведем исследовательский анализ данных
# - построим и обучим модель
#
#
# **Описание данных**
#
# Технологический процесс:
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate **— ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# Параметры этапов:
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# Наименование признаков:
#
# [этап].[тип_параметра].[название_параметра]<br>
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# - `rougher` — флотация
# - `primary_cleaner` — первичная очистка
# - `secondary_cleaner` — вторичная очистка
# - `final` — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# - `input` — параметры сырья
# - `output` — параметры продукта
# - `state` — параметры, характеризующие текущее состояние этапа
# - `calculation` — расчётные характеристики
#
#
# Данные индексируются датой и временем получения информации (признак date). <br>
# Соседние по времени параметры часто похожи.<br>
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. <br>
# Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. <br>
# Также в тестовом наборе нет целевых признаков.<br>
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.<br>
#
# В нашем распоряжении сырые данные: их просто выгрузили из хранилища.<br>
# Прежде чем приступить к построению модели, проверим данные на корректность.<br>
#
# -----------------------
#
# Инструкция по выполнению проекта
# 1. Подготовьте данные
# - Откройте файлы и изучите их.
# - Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.
# - Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# - Проведите предобработку данных.
# 2. Проанализируйте данные
# - Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.
# - Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# - Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# 3. Постройте модель
# - Напишите функцию для вычисления итоговой sMAPE.
# - Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# ____________________________________

# %%
import time
import math
import warnings
import numpy as np
import pandas as pd
from scipy import stats as st
from matplotlib.pyplot import cm
from matplotlib.cm import get_cmap

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor

# !pip install catboost
from catboost import CatBoostRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, make_scorer

import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')

pd.set_option('display.max_rows', None)
pd.options.mode.chained_assignment = None
warnings.filterwarnings(action="ignore", message="Mean of empty slice")
warnings.filterwarnings("ignore")

# %%
def get_info_on_dataset(_df):
    """
    Get review on given dataset

    :param _df: pandas dataframe with data
    :param _full: True - provides full review, False - otherwise
    :return: None
    """ 
    CONST_IN_PERCENTAGES = float(100.0)
    
    try:
        _df.info()
        df_review_info = pd.DataFrame({'Not_Valid_Values_in %': (_df.isna().sum()/len(_df))*CONST_IN_PERCENTAGES} )
        print("")
        display(df_review_info.sort_values(by='Not_Valid_Values_in %', ascending=False))
            
        print("")
        print("Number of duplicated rows in the dataset: {}".format(_df.duplicated().sum()))
            
    except:
        print("Can't provide review on given dataset")
    
    pass

# %%
def plot_df_coll_matrix(_df, 
                        _columns, 
                        _annotation = True,
                        _fiture_height = 15, 
                        _fiture_width = 15, 
                        _cell_annotation_font_size = 15,
                        _axiss_labels_font_size = 10):
    """ 
    Plot pairwise correlation matrix 
    :param _df_data: pandas dataframe with data
    :return: None 
    """   
    try:
        corr = _df[_columns].corr()
        fig, ax = plt.subplots(figsize=(_fiture_height, _fiture_width))           
        _pl = sns.heatmap(corr, 
                          ax=ax, 
                          annot=_annotation, 
                          linewidths=.5, 
                          fmt=".3f",
                          annot_kws={'size': _cell_annotation_font_size}, 
                          cmap='coolwarm',
                          square=True)
        
        _pl.set_yticklabels(ax.get_yticklabels(), size = _axiss_labels_font_size, fontweight = 'bold')
        _pl.set_xticklabels(ax.get_xticklabels(), size = _axiss_labels_font_size, fontweight = 'bold')
    except:
        print("Can't provide pairwise correlation plotting")    
    pass

# %%
def plot_info_on_numerical_column( _df, 
                                   _feature_title,
                                   _text_info = True,
                                   _bins = 50, 
                                   _figure_width = 20, 
                                   _figure_height = 12, 
                                   _fontsize=15,
                                   _number_of_decimals = 2):
    """ 
    Plot info on numerical feature
    param;  _df                    : pandas dataframe
    param:  _feature_title         : feature's column title
    param:  _bins:                 : hists bins number  
    param:  _fiture__width         : figure's width value
    param:  _fiture_height         : fiture's height value
    param:  _fontsize              : fontsize value
    :return                        : None 
    """     

    NCOLS_NUMBER_CONST = 2
    
    fig, ax = plt.subplots(ncols=NCOLS_NUMBER_CONST, figsize=(_figure_width, _figure_height))

    sns.histplot(data=_df, 
                 x=_feature_title, 
                 color="steelblue", 
                 label=_feature_title, 
                 bins=_bins, 
                 kde=True,
                 ax=ax[0])
        
    mean_value = _df[_feature_title].mean()  
    median_value = _df[_feature_title].median() 
    
    ax[0].axvline(x=mean_value, color='black', lw = 2, ls = ':', label = "mean: {}".format(round(
                                                                 mean_value, _number_of_decimals)))
    ax[0].axvline(x=median_value, color='blue', lw = 2, ls = '-.', label = "median: {}".format(round(
                                                                   median_value, _number_of_decimals)))

    ax[0].legend(fontsize = '15', title_fontsize = '10', loc='upper right') 
        
    plt.tight_layout()
    
    Q1_QUANTILE_VALUE_CONST = float(0.25)
    Q3_QUANTILE_VALUE_CONST = float(0.75)
    IQR_MULT_DEFAULT_CONST = float(1.5)
    
    Q1 = _df[_feature_title].quantile(Q1_QUANTILE_VALUE_CONST)
    Q3 = _df[_feature_title].quantile(Q3_QUANTILE_VALUE_CONST)
    IQR = Q3 - Q1 

            
    outliers_low_bound = Q1 - IQR_MULT_DEFAULT_CONST*IQR
    outliers_upper_bound = Q3 + IQR_MULT_DEFAULT_CONST*IQR      
    
    sns.boxplot(_df[_feature_title], color="steelblue", ax=ax[1])

    if _text_info:
        print("Q1 == {:.2f}, Q3 == {:.2f}, IQR == {:.2f}".format(Q1, Q3, IQR))
        print("[Q1 - 1.5*IQR] == {:.2f}, [Q3 + 1.5*IQR] == {:.2f}".format(outliers_low_bound, outliers_upper_bound))    

    plt.show()

# %%
def plot_features_hists(_df,
                        _features_column_list,
                        _bins = 50, 
                        _figure_width = 20, 
                        _figure_height = 12, 
                        _colormaps_title = "Pastel2",
                        _stat = 'count',
                        _fontsize=15):
    """ 
    Plot histograms
    param:  _df                    : pandas dataframe with data
    param:  _features_column_list  : features column titles 
    param:  _bins:                 : hists bins number  
    param:  _fiture__width         : figure's width value
    param:  _fiture_height         : fiture's height value
    param:  _fontsize              : fontsize value
    :return                        : None 
    """   
    try:
        hists_number = len(_features_column_list)
        plt.figure(figsize=(_figure_width, _figure_height))
        hist_colors = get_cmap(_colormaps_title).colors 

        for _c, i in zip(_features_column_list, range(hists_number)):
            sns.histplot(data=_df, 
                         x=_c, 
                         color=hist_colors[i], 
                         label= str(_c), 
                         bins = _bins, 
                         stat=_stat,
                         kde=True)
        
        plt.ylabel('', fontsize=_fontsize)
        plt.yticks(fontsize=_fontsize)
        plt.xticks(fontsize=_fontsize)
                       
        plt.legend( fontsize = '15', title_fontsize = '10')
        plt.show() 

    except:
        print("Can't provide boxplot plotting")
        
    pass

# %%
def plot_features_boxplot(_df,
                          _figure_width = 12, 
                          _figure_height = 8,
                          _color = 'c',
                          _fontsize=15):
    """ 
    Plot histograms
    param:  _df                    : pandas dataframe with data
    param:  _features_column_list  : features column titles 
    param:  _fiture__width         : figure's width value
    param:  _fiture_height         : fiture's height value
    param:  _fontsize              : fontsize value
    :return                        : None 
    """   
    try:

        fig, ax = plt.subplots(figsize=(_figure_width, _figure_height))
        
        _pl = sns.boxplot(data=_df, 
                          orient="h", 
                          color=_color)
        
        _pl.set_yticklabels(ax.get_yticklabels(), size = _fontsize, fontweight = 'bold')
        #_pl.set_xticklabels(ax.get_xticklabels(), size = _axiss_labels_font_size, fontweight = 'bold')
        plt.show() 
        
    except:
        print("Can't provide boxplot plotting")  
        
    pass

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Откройте файлы и изучите их

# %% [markdown]
# Загрузим данные, изучам информацию о файлах, выведем несколько строк таблиц и посмотрим корреляцию столбцов.

# %%
try:
    df_gold_recovery_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
    df_gold_recovery_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
    df_gold_recovery_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
except:
    df_gold_recovery_full = pd.read_csv('gold_recovery_full_new.csv')
    df_gold_recovery_test = pd.read_csv('gold_recovery_test_new.csv')
    df_gold_recovery_train = pd.read_csv('gold_recovery_train_new.csv')

# %%
print('')
print('Полная выборка')
print('')
get_info_on_dataset(df_gold_recovery_full)
print('')
print('Тестовая выборка')
print('')
get_info_on_dataset(df_gold_recovery_test)
print('')
print('Обучающая выборка')
print('')
get_info_on_dataset(df_gold_recovery_train)
# Out:
# Полная выборка
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
print('Полная выборка')
display(df_gold_recovery_full.head())
print('Тестовая выборка')
display(df_gold_recovery_test.head())
print('Обучающая выборка')
display(df_gold_recovery_train.head())
# Out:
# Полная выборка
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# Загрузили датасеты и ознакомились с данными. <br>
# У нас есть три таблицы:
# - df_gold_recovery_full - содержит 19 439 строк 87 столбцов
# - df_gold_recovery_test - содержит 5 290 строк 53 столбцов
# - df_gold_recovery_train - содержит 14 149 строк 87 столбцов
#
# Во всех датасетах есть незначительное количество пропусков, нет дубликатов, одна колонка с датой и все остальные столбцы с вещественным типом данных.

# %% [markdown]
# ### Проверка эффективности обогащения

# %% [markdown]
# Проверим эффективность обогащения в общей выборке. <br>
# Это показатель `rougher.output.recovery`. <br>
# Сделаем расчет по формуле и сравним с данными в таблице.

# %%
def get_rougher_output_recovery(_row):

    PERCENTAGE_COEFF_VALUE_CONST = float(100.0)
    
    C_value = _row['rougher.output.concentrate_au']
    F_value = _row['rougher.input.feed_au']
    T_value = _row['rougher.output.tail_au']
    
    processed_coeff_value = .0
    
    try:
        processed_coeff_value = ((C_value*(F_value-T_value))/(F_value*(C_value-T_value)))*PERCENTAGE_COEFF_VALUE_CONST
    except:
        pass
    
    return processed_coeff_value

# %%
rougher_output_recovery_caclucated = df_gold_recovery_full.apply(get_rougher_output_recovery, axis=1)

mae = mean_absolute_error(rougher_output_recovery_caclucated.values, 
                          df_gold_recovery_full['rougher.output.recovery'].values)

print('Фактическая эффективность обогащения:\n{}'.format(df_gold_recovery_full['rougher.output.recovery'].describe()))
print('')
print('Расчетная эффективность обогащения:\n{}'.format(rougher_output_recovery_caclucated.describe()))
print('')
print('MAE значение: {}'.format(round(mae, 20)))
print('')

plt.figure(figsize=(20, 20))
sns.histplot(data=df_gold_recovery_full['rougher.output.recovery'], 
                     label='эффективность обогащения фактическая', 
                     color='crimson', 
                     bins = 50, 
                     alpha = 0.3,
                     kde=True)
sns.histplot(data=rougher_output_recovery_caclucated, 
                     label='эффективность обогащения расчетная', 
                     color='c', 
                     bins = 50, 
                     alpha = 0.5,
                     kde=True)
plt.xlabel('Эффективность обогащения', fontsize=20)
plt.axvline(x=df_gold_recovery_full['rougher.output.recovery'].mean(), 
            color='black', lw = 5, ls = ':', alpha = 0.5, label = 'средняя фактическая')
plt.axvline(x=df_gold_recovery_full['rougher.output.recovery'].median(), 
            color='black', lw = 5, ls = ':', alpha = 0.5, label = 'медиана фактическая')
plt.axvline(x=rougher_output_recovery_caclucated.mean(), 
            color='blue', lw = 5, ls = ':', alpha = 0.5, label = 'средняя расчетная')
plt.axvline(x=rougher_output_recovery_caclucated.median(), 
            color='blue', lw = 5, ls = ':', alpha = 0.5, label = 'медиана расчетная')
plt.legend(fontsize=15);
# Out:
# Фактическая эффективность обогащения:
# count    19439.000000
# mean        83.328587
# std         14.148086
# min          0.000000
# 25%         81.037957
# 50%         86.188892
# 75%         90.010670
# max        100.000000
# Name: rougher.output.recovery, dtype: float64
#
# Расчетная эффективность обогащения:
# count    19439.000000
# mean        83.328587
# std         14.148086
# min         -0.000000
# 25%         81.037957
# 50%         86.188892
# 75%         90.010670
# max        100.000000
# dtype: float64
#
# MAE значение: 9.87405e-15

# %% [markdown]
# Можно сделать вывод, что расчетная эффективность обогащения совпадает с фактическими данными в таблице.

# %% [markdown]
# ### Анализ признаков недоступных в тестовой выборке

# %%
print('Размер тестовой выборки: ', df_gold_recovery_test.shape)
print('Размер обучающей выборки: ', df_gold_recovery_train.shape)
print('Размер полной выборки: ', df_gold_recovery_full.shape)
# Out:
# Размер тестовой выборки:  (5290, 53)
# Размер обучающей выборки:  (14149, 87)
# Размер полной выборки:  (19439, 87)

# %%
difference_1 = set(df_gold_recovery_test.columns).difference(set(df_gold_recovery_train.columns))
difference_2 = set(df_gold_recovery_train.columns).difference(set(df_gold_recovery_test.columns))
columns_diff_list = set.union(difference_2, difference_1)
print('Столбцы отсутствующие в тестовой выборке: ', len(columns_diff_list), 'шт')
columns_diff_list
# Out:
# Столбцы отсутствующие в тестовой выборке:  34 шт
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
# ...

# %%
plot_df_coll_matrix(df_gold_recovery_full, 
                    sorted(columns_diff_list),
                    _annotation = False,
                    _fiture_height = 25,                     
                    _fiture_width = 20, 
                    _cell_annotation_font_size = 5,
                    _axiss_labels_font_size = 20)

# %% [markdown]
# Таблица с тестовыми данными меньше обучающей и полной таблицы на 34 столбца. <br>
# Тестовые данные не содержат:
# - расчетные величины - признак `.calculation.`
# - выходные характеристики продукта - признак `.output.`
#
# Эти данные добавляют в таблицу на опередленных этапах процесса или после его завершения. <br>
# Также видим, что в признаках, которых нет в тестовой выборке есть немного параметров коррелириующих друг с другом.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# -------------------------------------
#
# Так как данные индексируются датой и временем получения информации, то в таблицах столбец `date` добавим в Индекс - далее пригодится для соединения признаков из разных датасетов.

# %%
df_gold_recovery_full.set_index('date', inplace=True)
df_gold_recovery_train.set_index('date', inplace=True)
df_gold_recovery_test.set_index('date', inplace=True)

# %%
print('Тестовая выборка')
display(df_gold_recovery_test.head(2))
print('Обучающая выборка')
display(df_gold_recovery_train.head(2))
print('Полная выборка')
display(df_gold_recovery_full.head(2))
# Out:
# Тестовая выборка
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
# 2016-09-01 01:59:59                             8.08
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# ...

# %% [markdown]
# #### обучающая выборка df_gold_recovery_train

# %% [markdown]
# Удалим из обучающей выборки все столбцы ненужные для обучения, кроме целевых признаков `rougher.output.recovery`, `final.output.recovery`. Проверим результат и посмотрим на корреляцию оставшихся данных.

# %%
columns_diff_list = list(set(columns_diff_list) - set(['rougher.output.recovery', 'final.output.recovery']))
print('Столбцы к удалению из df_gold_recovery_train: ', len(columns_diff_list), 'шт')
columns_diff_list
# Out:
# Столбцы к удалению из df_gold_recovery_train:  32 шт
# ['primary_cleaner.output.concentrate_au',
#  'rougher.output.concentrate_au',
#  'primary_cleaner.output.concentrate_ag',
#  'rougher.output.concentrate_ag',
#  'secondary_cleaner.output.tail_sol',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_pb',
#  'final.output.concentrate_au',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.tail_au',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.output.tail_sol',
#  'secondary_cleaner.output.tail_pb',
#  'final.output.concentrate_pb',
#  'final.output.tail_pb',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'secondary_cleaner.output.tail_ag',
#  'final.output.concentrate_sol',
#  'final.output.tail_ag',
#  'rougher.output.tail_ag',
#  'rougher.output.concentrate_sol',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.output.concentrate_pb',
# ...

# %%
df_gold_recovery_train = df_gold_recovery_train.drop(columns=columns_diff_list)
print('Размер тестовой выборки: ', df_gold_recovery_test.shape)
print('Размер обучающей выборки: ', df_gold_recovery_train.shape)
print('Размер полной выборки: ', df_gold_recovery_full.shape)
# Out:
# Размер тестовой выборки:  (5290, 52)
# Размер обучающей выборки:  (14149, 54)
# Размер полной выборки:  (19439, 86)

# %%
print('Тестовая выборка')
display(df_gold_recovery_test.head(2))
print('Обучающая выборка')
display(df_gold_recovery_train.head(2))
print('Полная выборка')
display(df_gold_recovery_full.head(2))
# Out:
# Тестовая выборка
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
# 2016-09-01 01:59:59                             8.08
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# ...

# %% [markdown]
# Разница в колонках обучающей и тестовой выборки.

# %%
df_gold_recovery_train.columns.difference(df_gold_recovery_test.columns).tolist()
# Out:
# ['final.output.recovery', 'rougher.output.recovery']

# %%
plot_df_coll_matrix(df_gold_recovery_train, 
                    sorted(df_gold_recovery_train.columns),
                    _annotation = False,
                    _fiture_height = 25,                     
                    _fiture_width = 20, 
                    _cell_annotation_font_size = 5,
                    _axiss_labels_font_size = 20)

# %% [markdown]
# В обучающей выборке явно есть признаки с высокой корреляцией.

# %% [markdown]
# --------------------------------------
# Также видим, что в обучающей выборке есть пропуски, попробуем их заполнить методом линейной интерполяции

# %%
get_info_on_dataset(df_gold_recovery_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   final.output.recovery                       14149 non-null  float64
#  1   primary_cleaner.input.sulfate               14129 non-null  float64
#  2   primary_cleaner.input.depressant            14117 non-null  float64
#  3   primary_cleaner.input.feed_size             14149 non-null  float64
#  4   primary_cleaner.input.xanthate              14049 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_air      14145 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_level    14148 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_air      14145 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_level    14148 non-null  float64
# ...

# %%
display(df_gold_recovery_train[df_gold_recovery_train['rougher.state.floatbank10_e_air'] 
                        != df_gold_recovery_train['rougher.state.floatbank10_e_air']].head().T)
display(df_gold_recovery_full[df_gold_recovery_full['rougher.state.floatbank10_e_air'] 
                        != df_gold_recovery_full['rougher.state.floatbank10_e_air']].head().T)
# Out:
# date                                        2018-01-13 06:59:59  \
# final.output.recovery                                 57.557984
# primary_cleaner.input.sulfate                        171.875602
# primary_cleaner.input.depressant                      10.509944
# primary_cleaner.input.feed_size                        7.820000
# primary_cleaner.input.xanthate                         0.954376
# primary_cleaner.state.floatbank8_a_air              1497.719816
# primary_cleaner.state.floatbank8_a_level            -499.233295
# primary_cleaner.state.floatbank8_b_air              1497.761434
# primary_cleaner.state.floatbank8_b_level            -500.443690
# primary_cleaner.state.floatbank8_c_air              1499.308378
# primary_cleaner.state.floatbank8_c_level            -498.958915
# primary_cleaner.state.floatbank8_d_air              1500.660136
# primary_cleaner.state.floatbank8_d_level            -499.306001
# rougher.input.feed_ag                                 12.779133
# ...

# %%
print('Значение rougher.state.floatbank10_e_air с индексом "2018-01-13 06:59:59" из обучающей выборки до заполнения:', 
  df_gold_recovery_train.loc[df_gold_recovery_train.index == '2018-01-13 06:59:59','rougher.state.floatbank10_e_air'],'\n')
print('Значение rougher.state.floatbank10_e_air с индексом "2018-01-13 06:59:59" из полной выборки:', 
  df_gold_recovery_full.loc[df_gold_recovery_full.index == '2018-01-13 06:59:59','rougher.state.floatbank10_e_air'])
# Out:
# Значение rougher.state.floatbank10_e_air с индексом "2018-01-13 06:59:59" из обучающей выборки до заполнения: date
# 2018-01-13 06:59:59   NaN
# Name: rougher.state.floatbank10_e_air, dtype: float64
#
# Значение rougher.state.floatbank10_e_air с индексом "2018-01-13 06:59:59" из полной выборки: date
# 2018-01-13 06:59:59   NaN
# Name: rougher.state.floatbank10_e_air, dtype: float64

# %% [markdown]
# _____________________________
# Заполним пропуски в обучающей таблице на основании данных полной выборки с применением к ней метода линейной интерполяции. <br>

# %%
main_features_columns = df_gold_recovery_train.columns
df_gold_recovery_train = pd.DataFrame(index=df_gold_recovery_train.index)
df_gold_recovery_train = df_gold_recovery_train.join(
    df_gold_recovery_full[main_features_columns].interpolate(method='linear'))

# %%
get_info_on_dataset(df_gold_recovery_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   final.output.recovery                       14149 non-null  float64
#  1   primary_cleaner.input.sulfate               14149 non-null  float64
#  2   primary_cleaner.input.depressant            14149 non-null  float64
#  3   primary_cleaner.input.feed_size             14149 non-null  float64
#  4   primary_cleaner.input.xanthate              14149 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_air      14149 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_level    14149 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_air      14149 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_level    14149 non-null  float64
# ...

# %% [markdown]
# _________________________________________________
# Далее посмотрим на гистограммы и ящики с усами по столбцам подготовленной обучающей выборки.
# Получилось много графиков, но достаточно информативно.

# %%
def plot_df_features_info(_df):
    for _c in _df.columns:
        plot_info_on_numerical_column(_df, _c, _figure_width = 16, _figure_height = 6)

# %%
# закомментировали, т.к. очень много графиков
# plot_df_features_info(df_gold_recovery_train)

# %% [markdown]
# #### тестовая выборка df_gold_recovery_test

# %%
get_info_on_dataset(df_gold_recovery_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5290 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 52 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5286 non-null   float64
#  1   primary_cleaner.input.depressant            5285 non-null   float64
#  2   primary_cleaner.input.feed_size             5290 non-null   float64
#  3   primary_cleaner.input.xanthate              5286 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
# ...

# %% [markdown]
# В тестовой выборке пропусков очень мало, поэтому просто удалим их из датасета. Не будем заполнять синтетическими данными таблицу для проверки работы модели, оставим только фактическую информацию.
#
# Так же добавим в тестовую выборку целевые признаки из полной таблицы по индексу-дате.

# %%
df_gold_recovery_test.dropna(inplace=True)

# %%
df_gold_recovery_test = df_gold_recovery_test.merge(df_gold_recovery_full[['rougher.output.recovery', 
                                                                           'final.output.recovery']], 
                                                                            on='date',
                                                                            how='left')

# %%
get_info_on_dataset(df_gold_recovery_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5229 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5229 non-null   float64
#  1   primary_cleaner.input.depressant            5229 non-null   float64
#  2   primary_cleaner.input.feed_size             5229 non-null   float64
#  3   primary_cleaner.input.xanthate              5229 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5229 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5229 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5229 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5229 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5229 non-null   float64
# ...

# %%
plot_df_coll_matrix(df_gold_recovery_test, 
                    sorted(df_gold_recovery_test.columns),
                    _annotation = False,
                    _fiture_height = 25,                     
                    _fiture_width = 20, 
                    _cell_annotation_font_size = 5,
                    _axiss_labels_font_size = 20)

# %%
print('Размер тестовой выборки: ', df_gold_recovery_test.shape)
print('Размер обучающей выборки: ', df_gold_recovery_train.shape)
print('Размер полной выборки: ', df_gold_recovery_full.shape)
# Out:
# Размер тестовой выборки:  (5229, 54)
# Размер обучающей выборки:  (14149, 54)
# Размер полной выборки:  (19439, 86)

# %% [markdown]
# __________________________
# Мы обработали и подготовили данные для последующей работы.
# - назначили индексируемым столбцом столбец `date`
# - удалили из обучающей выборки столбцы ненужные для обучения модели
# - заполнили пропуски в обучающей выборке (методом линейной интерполяции на основании данных полной выборки)
# - удалили строки с пропусками из тестовой выборки (количество их было незначительно, и чтобы избежать проверку модели синтетическими данными)
# - добавили в тестовую выборку столбцы с целевыми признаками из полной таблицы
# - изучили данные и их корреляции
#
# Приступим к анализу данных.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Изменение концентрации металлов Au, Ag, Pb

# %% [markdown]
# Посмотрим на изменение концетрации металлов Au (золото), Ag (серебро), Pb (свинец) на каждом этапе производственного процесса.

# %% [markdown]
# ___________
# **Концентрация Au (золото)**

# %%
au_related_columns = ['rougher.input.feed_au',                 # исходное сырье
                      'rougher.output.concentrate_au',         # после флотации
                      'primary_cleaner.output.concentrate_au', # после первичной очистки
                      'final.output.concentrate_au']           # финальные параметры продукта

df_gold_recovery_full[au_related_columns].mean()
# Out:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64

# %%
plot_features_hists(df_gold_recovery_full, au_related_columns)#, _stat='density')

# %%
plot_features_boxplot(df_gold_recovery_full[au_related_columns],_color = 'paleturquoise')

# %% [markdown]
# ___________
# **Концентрация Ag (серебро)**

# %%
ag_related_columns = ['rougher.input.feed_ag',                 # исходное сырье
                      'rougher.output.concentrate_ag',         # после флотации
                      'primary_cleaner.output.concentrate_ag', # после первичной очистки
                      'final.output.concentrate_ag']           # финальные параметры продукта

df_gold_recovery_full[ag_related_columns].mean()
# Out:
# rougher.input.feed_ag                     8.794927
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168470
# dtype: float64

# %%
plot_features_hists(df_gold_recovery_full, ag_related_columns) #, _stat='density')

# %%
plot_features_boxplot(df_gold_recovery_full[ag_related_columns], _color = 'paleturquoise')

# %% [markdown]
# ___________
# **Концентрация Pb (свинец)**

# %%
pb_related_columns = ['rougher.input.feed_pb',                 # исходное сырье
                      'rougher.output.concentrate_pb',         # после флотации
                      'primary_cleaner.output.concentrate_pb', # после первичной очистки
                      'final.output.concentrate_pb']           # финальные параметры продукта

df_gold_recovery_full[pb_related_columns].mean()
# Out:
# rougher.input.feed_pb                    3.598085
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.829530
# final.output.concentrate_pb              9.978895
# dtype: float64

# %%
plot_features_hists(df_gold_recovery_full, pb_related_columns)#, _stat='density')

# %%
plot_features_boxplot(df_gold_recovery_full[pb_related_columns], _color = 'paleturquoise')

# %% [markdown]
# ------------------------
# По графикам можем сделать вывод, что разные металлы ведут себя по-разному в процессе очистки:
# - концентрация **Au** золота в серье после каждого этапа повышается
# - концентрация **Ag** серебра после финальной очистки ниже, чем в исходом сырье
# - концентрация **Pb** свинца растет в процесе очистки, но после первичной и вторичной очистки данные почти одинаковые

# %% [markdown]
# ### Распределение размеров гранул сырья на обучающей и тестовой выборках

# %% [markdown]
# Сравним распределение размеров гранул сырья на обучающей и тестовой выборках. <br>
# Если распределения будут сильно отличаться друг от друга,  то оценка модели может быть неправильной.

# %%
# rougher.input.feed_size         - размер гранул сырья перед флотацией
# primary_cleaner.input.feed_size - размер гранул сырья перед первичной очисткой

df_feed_size = pd.DataFrame()

df_feed_size['train_rougher.input.feed_size'] = df_gold_recovery_train['rougher.input.feed_size'].reset_index(drop=True)
df_feed_size['test_rougher.input.feed_size'] = df_gold_recovery_test['rougher.input.feed_size'].reset_index(drop=True)
df_feed_size['train_primary_cleaner.input.feed_size'] = df_gold_recovery_train['primary_cleaner.input.feed_size']\
                                                                                .reset_index(drop=True)
df_feed_size['test_primary_cleaner.input.feed_size'] = df_gold_recovery_test['primary_cleaner.input.feed_size']\
                                                                                .reset_index(drop=True)

# %%
df_feed_size.describe()
# Out:
#        train_rougher.input.feed_size  test_rougher.input.feed_size  \
# count                   14149.000000                   5229.000000
# mean                       60.097903                     55.863978
# std                        23.023690                     18.914656
# min                         9.659576                      0.046369
# 25%                        48.950593                     43.911874
# 50%                        55.269784                     50.772729
# 75%                        65.982466                     62.265394
# max                       484.967466                    392.494040
#
#        train_primary_cleaner.input.feed_size  \
# count                           14149.000000
# mean                                7.322310
# std                                 0.614062
# min                                 1.080000
# 25%                                 6.960000
# 50%                                 7.290000
# ...

# %%
primary_cleaner_feed_related_columns = ['train_primary_cleaner.input.feed_size', 'test_primary_cleaner.input.feed_size']

plot_features_hists(df_feed_size, 
                    primary_cleaner_feed_related_columns, 
                    _colormaps_title = "Pastel1", 
                    _stat='density')

# %%
plot_features_boxplot(df_feed_size[primary_cleaner_feed_related_columns], _color = 'paleturquoise')

# %%
rougher_feed_related_columns = ['train_rougher.input.feed_size', 'test_rougher.input.feed_size']

plot_features_hists(df_feed_size, 
                    rougher_feed_related_columns, 
                    _colormaps_title = "Pastel1", 
                    _stat='density')

# %%
plot_features_boxplot(df_feed_size[rougher_feed_related_columns], _color = 'paleturquoise')

# %% [markdown]
# _______________________________
#
# Сравнили распределение размеров гранул сырья на обучающей и тестовой выборках перед флотацией ` rougher.input.feed_size` и перед первичной очисткой `primary_cleaner.input.feed_size`. <br>
# Для каждого этапа производства распределения тестовой и обучающей выборок не сильно отличаются друг от друга, поэтому не должно быть значительного влияния на модель.

# %% [markdown]
# ### Анализ суммарной концентрации всех веществ на разных стадиях: в сырье, черновом и финальном концентратах

# %% [markdown]
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
#параметры сырья перед флотацией
rougher_input_related_columns = ['rougher.input.feed_au',  #золото
                                 'rougher.input.feed_ag',  #серебро
                                 'rougher.input.feed_pb',  #свинец
                                 'rougher.input.feed_sol'] #??

#параметры продукта после флотации
rougher_output_related_columns = ['rougher.output.concentrate_au', 
                                  'rougher.output.concentrate_ag', 
                                  'rougher.output.concentrate_pb', 
                                  'rougher.output.concentrate_sol']

#параметры продукта после первичной очистки
primary_cleaner_related_columns = ['primary_cleaner.output.concentrate_au',
                                   'primary_cleaner.output.concentrate_ag', 
                                   'primary_cleaner.output.concentrate_pb', 
                                   'primary_cleaner.output.concentrate_sol']

#финальные параметры продукта после вторичной очистки
final_output_related_columns = ['final.output.concentrate_au', 
                                'final.output.concentrate_ag', 
                                'final.output.concentrate_pb', 
                                'final.output.concentrate_sol']

# %%
df_all_substances_all_stages = pd.DataFrame()

df_all_substances_all_stages['rougher_input'] = df_gold_recovery_full[rougher_input_related_columns].sum(axis=1)
df_all_substances_all_stages['rougher_output'] = df_gold_recovery_full[rougher_output_related_columns].sum(axis=1)
df_all_substances_all_stages['primary_cleaner'] = df_gold_recovery_full[primary_cleaner_related_columns].sum(axis=1)
df_all_substances_all_stages['final_output'] = df_gold_recovery_full[final_output_related_columns].sum(axis=1)

df_all_substances_all_stages.head(3)
# Out:
#                      rougher_input  rougher_output  primary_cleaner  \
# date
# 2016-01-15 00:00:00      51.680034       66.424950        72.640924
# 2016-01-15 01:00:00      50.659114       67.012710        72.543485
# 2016-01-15 02:00:00      50.609929       66.103793        72.095042
#
#                      final_output
# date
# 2016-01-15 00:00:00     63.644396
# 2016-01-15 01:00:00     63.957723
# 2016-01-15 02:00:00     64.311180

# %%
df_all_substances_all_stages.describe()
# Out:
#        rougher_input  rougher_output  primary_cleaner  final_output
# count   19439.000000    19439.000000     19439.000000  19439.000000
# mean       57.148832       68.144520        60.622525     68.621192
# std         7.712767       12.540021        10.202580      7.461966
# min         0.040000        0.000000         0.000000      0.000000
# 25%        53.507961       66.003784        58.883626     67.928471
# 50%        57.577384       70.177013        62.491150     69.598046
# 75%        61.951075       74.356904        65.665299     71.368472
# max        76.978947       88.140119        80.749343     80.210644

# %%
plot_features_hists(df_all_substances_all_stages, 
                    df_all_substances_all_stages.columns, 
                    _colormaps_title = "Set2")#, 
                    #_stat='density')

# %%
plot_features_boxplot(df_all_substances_all_stages, _color = 'paleturquoise')

# %%
print('Количество нулевых значений в исходном сырье:        ', 
      df_all_substances_all_stages.query('rougher_input == 0').value_counts().count())
print('Количество нулевых значений после флотации:          ', 
      df_all_substances_all_stages.query('rougher_output == 0').value_counts().count())
print('Количество нулевых значений после первичной очистки: ', 
      df_all_substances_all_stages.query('primary_cleaner == 0').value_counts().count())
print('Количество нулевых значений в финальном продукте:    ', 
      df_all_substances_all_stages.query('final_output == 0').value_counts().count())
# Out:
# Количество нулевых значений в исходном сырье:         0
# Количество нулевых значений после флотации:           394
# Количество нулевых значений после первичной очистки:  95
# Количество нулевых значений в финальном продукте:     98

# %%
plt.figure(figsize=(30, 20))
sns.histplot(data=df_all_substances_all_stages, color="Set2", bins = 100)
plt.xlim([0, 5])
plt.ylim([0, 450])
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# Из полного датасета df_gold_recovery_full удалим строки с нулевыми для некоторых признаков значениями.

# %%
ZERO_VALUE_THRESHOLD_VALUE_CONST = float(0.5)

zero_value_threshold_related_columns =  ['rougher.output.recovery',
                                         'final.output.recovery',
    
                                         'rougher.input.feed_ag',
                                         'rougher.output.concentrate_ag', 
                                         'primary_cleaner.output.concentrate_ag', 
                                         'final.output.concentrate_ag',

                                         'rougher.input.feed_au',
                                         'rougher.output.concentrate_au', 
                                         'primary_cleaner.output.concentrate_au', 
                                         'final.output.concentrate_au',

                                         'rougher.input.feed_pb',
                                         'rougher.output.concentrate_pb', 
                                         'primary_cleaner.output.concentrate_pb', 
                                         'final.output.concentrate_pb']

# %%
df_gold_recovery_full_final = df_gold_recovery_full.copy()

# %%
print("Размер полной выборки до удаления выбросов по некоторым из признаков:{}".format(df_gold_recovery_full_final.shape))

for _col in zero_value_threshold_related_columns:
    df_gold_recovery_full_final = \
                    df_gold_recovery_full_final[df_gold_recovery_full_final[_col] > ZERO_VALUE_THRESHOLD_VALUE_CONST]

print("Размер полной выборки после удаления выбросов по некоторым из признаков:{}"\
      .format(df_gold_recovery_full_final.shape))
# Out:
# Размер полной выборки до удаления выбросов по некоторым из признаков:(19439, 86)
# Размер полной выборки после удаления выбросов по некоторым из признаков:(18516, 86)

# %%
main_features_columns = df_gold_recovery_test.columns

# %%
df_gold_recovery_train = pd.DataFrame(index=df_gold_recovery_train.index)
df_gold_recovery_train = \
        df_gold_recovery_train.join(df_gold_recovery_full_final[main_features_columns].interpolate(method='linear'))
df_gold_recovery_train.dropna(inplace=True)

df_gold_recovery_test = pd.DataFrame(index=df_gold_recovery_test.index)
df_gold_recovery_test = \
        df_gold_recovery_test.join(df_gold_recovery_full_final[main_features_columns].interpolate(method='linear'))
df_gold_recovery_test.dropna(inplace=True)

# %%
get_info_on_dataset(df_gold_recovery_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5054 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5054 non-null   float64
#  1   primary_cleaner.input.depressant            5054 non-null   float64
#  2   primary_cleaner.input.feed_size             5054 non-null   float64
#  3   primary_cleaner.input.xanthate              5054 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5054 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5054 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5054 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5054 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5054 non-null   float64
# ...

# %% [markdown]
# __________________________________________________
# По графикам видно, что суммарные концентрации веществ на разных стадиях меняются.<br>
# Средние и медианные значения после флотации выросли, после первичной очистки снизились, а после финальной стадии возросли примерно до уровня после флотации.<br>
# Но на финальном этапе распределение стало более узким и высоким.<br>
# Также видим, что есть достаточно много нулевых значений.<br>
# Но на этапе исходного сырья таких значений нет, много после флотации, меньше после очистки.<br>
# Можно предполжить, что после флотации есть ошибка в измерениях, либо просто отсутствие этих измерений.<br>
# Удалили из выборок строки с нулевыми параметрами.

# %% [markdown]
# ## Построение модели

# %% [markdown]
# Разделим обучающую и тестовую выборки на обучающие признаки и целевые.

# %%
df_features_training = df_gold_recovery_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
df_target_training_ror = df_gold_recovery_train['rougher.output.recovery']
df_target_training_for = df_gold_recovery_train['final.output.recovery']

df_features_testing = df_gold_recovery_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
df_target_testing_ror = df_gold_recovery_test['rougher.output.recovery']
df_target_testing_for = df_gold_recovery_test['final.output.recovery']

# %%
print('Размер обучающей выборки обучающие признаки: ', df_features_training.shape)
print('Размер обучающей выборки rougher.output.recovery : ', df_target_training_ror.shape)
print('Размер обучающей выборки final.output.recovery: ', df_target_training_for.shape)
print('Размер тестовой выборки обучающие признаки: ', df_features_testing.shape)
print('Размер тестовой выборки rougher.output.recovery : ', df_target_testing_ror.shape)
print('Размер тестовой выборки final.output.recovery: ', df_target_testing_for.shape)
# Out:
# Размер обучающей выборки обучающие признаки:  (13419, 52)
# Размер обучающей выборки rougher.output.recovery :  (13419,)
# Размер обучающей выборки final.output.recovery:  (13419,)
# Размер тестовой выборки обучающие признаки:  (5054, 52)
# Размер тестовой выборки rougher.output.recovery :  (5054,)
# Размер тестовой выборки final.output.recovery:  (5054,)

# %%
print('\n Обучающая выборка обучающие признаки')
display(df_features_training.head(2))
print('\n Обучающая выборка целевые признаки rougher.output.recovery')
display(df_target_training_ror.head(2))
print('\n Обучающая выборка целевые признаки final.output.recovery')
display(df_target_training_for.head(2))
print('\n Тестовая выборка обучающие признаки')
display(df_features_testing.head(2))
print('\n Тестовая выборка целевые признаки rougher.output.recovery')
display(df_target_testing_ror.head(2))
print('\n Тестовая выборка целевые признаки final.output.recovery')
display(df_target_testing_for.head(2))
# Out:
#  Обучающая выборка обучающие признаки
#                      primary_cleaner.input.sulfate  \
# date
# 2016-01-15 00:00:00                     127.092003
# 2016-01-15 01:00:00                     125.629232
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-01-15 00:00:00                         10.128295
# 2016-01-15 01:00:00                         10.296251
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-01-15 00:00:00                             7.25
# 2016-01-15 01:00:00                             7.25
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-01-15 00:00:00                        0.988759
# 2016-01-15 01:00:00                        1.002663
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-01-15 00:00:00                             1549.775757
# 2016-01-15 01:00:00                             1576.166671
#
# ...

# %% [markdown]
# После разбиения данных на таблицы с целевыми признаками и признаками для обучения - отмасштабируем данные содержащие признаки, чтобы в них один признак не перевешивал другие.

# %%
scl_columns = df_features_training.columns
std_scaler = StandardScaler()
std_scaler.fit(df_features_training[scl_columns])

df_features_training[scl_columns] = std_scaler.transform(df_features_training[scl_columns])
df_features_testing[scl_columns] = std_scaler.transform(df_features_testing[scl_columns])

# %%
print('\n Обучающая выборка обучающие признаки')
display(df_features_training.head(2))
print('\n Тестовая выборка обучающие признаки')
display(df_features_testing.head(2))
# Out:
#  Обучающая выборка обучающие признаки
#                      primary_cleaner.input.sulfate  \
# date
# 2016-01-15 00:00:00                      -0.207549
# 2016-01-15 01:00:00                      -0.246222
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-01-15 00:00:00                          0.363594
# 2016-01-15 01:00:00                          0.413953
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-01-15 00:00:00                        -0.139166
# 2016-01-15 01:00:00                        -0.139166
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-01-15 00:00:00                        0.278191
# 2016-01-15 01:00:00                        0.315185
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-01-15 00:00:00                               -0.454867
# 2016-01-15 01:00:00                               -0.246332
#
# ...

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %% [markdown]
# Напишем функцию для вычисления метрики моделей **sMAPE**, итоговая **sMAPE**. <br>
# **sMAPE** - symmetric mean absolute percentage error / симметричная средняя абсолютная процентная ошибка.

# %%
def sMAPE (target, predictions):
    return 100 / len(target) * np.sum(2 * np.abs(predictions - target) / (np.abs(target) + np.abs(predictions)))


def sMAPE_final (rougher, final):
    return 0.25 * rougher + 0.75 * final

smape_score = make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# ### Обучение моделей и оценка их качества

# %% [markdown]
# Создадим несколько моделей машинного обучения:
# - RandomForestRegressor - Случайный лес
# - DecisionTreeRegressor - Дерево решений
# - LinearRegression - Линейная регрессия
# - CatBoostRegressor - Катбуст
#
# и подберем для них оптимальные гиперпараметры. <br>
# Выберем лучшую модель с наилучшим значением sMAPE. <br>

# %%
CV = KFold()
RANDOM_STATE = 424

pipe = Pipeline([('model', LinearRegression())])

_param_grid = [
    {
        'model': [RandomForestRegressor(random_state=RANDOM_STATE)],
        'model__max_depth': [2, 6, 10],
        'model__n_estimators': [10, 50, 100],
        'model__min_samples_leaf': [2, 4, 6],
        'model__min_samples_split': [2, 4, 6],
    }, {
        'model': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'model__max_depth': [2, 6, 10],
        'model__min_samples_leaf': [2, 4, 6],
        'model__min_samples_split': [2, 4, 6],
    }, {
        'model': [LinearRegression()],
    }, {
        'model': [CatBoostRegressor()],
        'model__depth': [2, 6, 10],
        'model__iterations': [4, 16, 32],
        'model__learning_rate': [1.0, 0.25, 0.05],
    }
]

# %% [markdown]
# ___________
# **Закомментирую подбор гиперпараметров - долгий расчет**

# %%
#start = time.time()
#print('Старт поиска лучшей модели и параметров для rougher.output.recovery ...')
      
#grid_ror = GridSearchCV(estimator=pipe, param_grid=_param_grid, cv=CV, scoring=smape_score, n_jobs=-1)
#grid_ror.fit(df_features_training, df_target_training_ror)
      
#print('Оптимальные модель и параметры для rougher.output.recovery найдены ...')
#end = time.time()
#print('\n Время подбора {} минут.'.format( round((end - start)/60, 2)))
#print('\n Лучшая модель: ', grid_ror.best_estimator_)
#print('\n Лучшие параметры: ', grid_ror.best_params_)
#print('\n Лучшая оценка sMAPE: ', round(np.abs(grid_ror.best_score_), 2))

# %%
#start = time.time()
#print('Старт поиска лучшей модели и параметров для final.output.recovery ...')
      
#grid_for = GridSearchCV(estimator=pipe, param_grid=_param_grid, cv=CV, scoring=smape_score, n_jobs=-1)
#grid_for.fit(df_features_training, df_target_training_for)
      
#print('Оптимальные модель и параметры для final.output.recovery найдены ...')
#end = time.time()
#print('\n Время подбора {} минут'.format( round((end - start)/60, 2)))
#print('\n Лучшая модель: ', grid_for.best_estimator_)
#print('\n Лучшие параметры: ', grid_for.best_params_)
#print('\n Лучшая оценка sMAPE: ', round(np.abs(grid_for.best_score_), 2))

# %% [markdown]
# Для каждого из признаков оказалась лучшей модель CatBoostRegressor, но с разными параметрами:
# - для `rougher.output.recovery` - CatBoostRegressor depth=10, iterations=16, learning_rate=0.25, sMAPE = 5.94
# - для `final.output.recovery` - CatBoostRegressor depth=6, iterations=32, learning_rate=0.05, sMAPE = 8.53

# %% [markdown]
# ### Выбор лучшей модели и проверка на тестовой выборке

# %% [markdown]
# Возьмем лучшие модели с лучшими параметрами и проверим их на тестовой выборке.

# %%
model_cb_1 = CatBoostRegressor(depth=10, 
                               iterations=16, 
                               learning_rate=0.25)
model_ror = model_cb_1.fit(df_features_training, df_target_training_ror)
predict_ror = model_ror.predict(df_features_testing)

model_cb_2 = CatBoostRegressor(depth=6, 
                               iterations=32, 
                               learning_rate=0.05)
model_cb_for = model_cb_2.fit(df_features_training, df_target_training_for)
cb_predict_for = model_cb_for.predict(df_features_testing)

smape_ror = sMAPE(df_target_testing_ror, predict_ror)
smape_for = sMAPE(df_target_testing_for, cb_predict_for)
smape_fin = sMAPE_final(smape_ror, smape_for)

print('Показатель sMAPE для rougher.output.recovery CatBoostRegressor: ', round(smape_ror, 2))
print('Показатель sMAPE для final.output.recovery CatBoostRegressor:       ', round(smape_for, 2))
print('Итоговый sMAPE для тестовой выборки:                                ', round(smape_fin, 2))
# Out:
# 0:	learn: 6.7849435	total: 210ms	remaining: 3.15s
# 1:	learn: 5.9825185	total: 294ms	remaining: 2.06s
# 2:	learn: 5.4185672	total: 376ms	remaining: 1.63s
# 3:	learn: 4.9706148	total: 463ms	remaining: 1.39s
# 4:	learn: 4.6693298	total: 559ms	remaining: 1.23s
# 5:	learn: 4.4228704	total: 644ms	remaining: 1.07s
# 6:	learn: 4.2154523	total: 738ms	remaining: 948ms
# 7:	learn: 4.0388055	total: 826ms	remaining: 826ms
# 8:	learn: 3.9305503	total: 912ms	remaining: 709ms
# 9:	learn: 3.8040882	total: 1.02s	remaining: 610ms
# 10:	learn: 3.7184013	total: 1.11s	remaining: 505ms
# 11:	learn: 3.6364748	total: 1.2s	remaining: 400ms
# 12:	learn: 3.5566871	total: 1.29s	remaining: 298ms
# 13:	learn: 3.4960348	total: 1.38s	remaining: 198ms
# 14:	learn: 3.4267141	total: 1.48s	remaining: 98.6ms
# 15:	learn: 3.3695294	total: 1.59s	remaining: 0us
# 0:	learn: 8.6524790	total: 12.9ms	remaining: 400ms
# 1:	learn: 8.5180364	total: 22.1ms	remaining: 332ms
# 2:	learn: 8.3938657	total: 30.4ms	remaining: 294ms
# ...

# %% [markdown]
# ______________________
# Проверим адекватность модели на фиктивном регрессоре DummyRegressor на основе двух простых стратегий:
# - среднее - всегда предсказывает среднее значение целевых значений
# - медиана - используется для прогнозирования медианы целевых значений тренировки

# %%
model_dummy_r = DummyRegressor(strategy='mean')
model_dummy_f = DummyRegressor(strategy='mean')
dummy_ror = model_dummy_r.fit(df_features_training, df_target_training_ror)
dummy_predict_ror = dummy_ror.predict(df_target_testing_ror)
dummy_for = model_dummy_f.fit(df_features_training, df_target_training_for)
dummy_predict_for = dummy_for.predict(df_target_testing_for)

smape_ror_dummy = sMAPE(df_target_testing_ror, dummy_predict_ror)
smape_for_dummy = sMAPE(df_target_testing_for, dummy_predict_for)
smape_fin_dummy = sMAPE_final(smape_ror_dummy, smape_for_dummy)
print('Итоговый sMAPE для DummyRegressor стратегия среднее', round(smape_fin_dummy, 2))

model_dummy_r = DummyRegressor(strategy='median')
model_dummy_f = DummyRegressor(strategy='median')
dummy_ror = model_dummy_r.fit(df_features_training, df_target_training_ror)
dummy_predictions_ror = dummy_ror.predict(df_target_testing_ror)
dummy_for = model_dummy_f.fit(df_features_training, df_target_training_for)
dummy_predictions_for = dummy_for.predict(df_target_testing_for)

smape_ror_dummy = sMAPE(df_target_testing_ror, dummy_predict_ror)
smape_for_dummy = sMAPE(df_target_testing_for, dummy_predict_for)
smape_fin_dummy = sMAPE_final(smape_ror_dummy, smape_for_dummy)
print('Итоговый sMAPE для DummyRegressor стратегия медиана', round(smape_fin_dummy, 2))
# Out:
# Итоговый sMAPE для DummyRegressor стратегия среднее 7.48
# Итоговый sMAPE для DummyRegressor стратегия медиана 7.48

# %% [markdown]
# Модели на фиктивном регрессоре DummyRegressor со стратегией "среднее" и "медиана" показали одинаковые значения Итогового sMAPE = **7.48**
#
# Наши модели предсказывают с меньшим sMAPE = **6.43**, чем фиктивный регрессор (среднее/медиана). <br>
# Можно сделать вывод, что полученные модели адекватны.

# %% [markdown]
# ___________________
# ## Вывод
#
# В ходе проекта было необходимо подготовить прототип модели машинного обучения для компании «Цифры». <br>
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.<br>
# В нашем распоряжении были данные с параметрами добычи и очистки.<br>
#
# Обработали и подготовили данные для последующей работы:
# - проверили расчет эффективности обогащения - расчет совпал с фактическими данными в таблице
# - удалили из обучающей выборки столбцы ненужные для обучения модели (расчетные величины и выходные характеристики продукта)
# - заполнили пропуски в обучающей выборке (методом линейной интерполяции)
# - удалили строки с пропусками из тестовой выборки
# - добавили в тестовую выборку столбцы с целевыми признаками из полной таблицы
#
# Проанализировали исходную информацию:
# - установили, что разные металлы ведут себя по-разному в процессе очистки:
#   - концентрация Au золота в серье после каждого этапа повышается
#   - концентрация Ag серебра после финальной очистки ниже, чем в исходом сырье
#   - концентрация Pb свинца растет в процесе очистки, но после первичной и вторичной очистки данные почти одинаковые
# - выяснили, что распределение размеров гранул сырья на обучающей и тестовой выборках перед флотацией и перед первичной очисткой похожи (не должно быть значительного влияния на модель)
# - обнаружили, что суммарные концентрации веществ на разных стадиях меняются - средние и медианные значения после флотации выросли, после первичной очистки снизились, а после финальной стадии возросли примерно до уровня после флотации
# - нашли много нулевых значений суммарной концентрации веществ - очень похоже на ошибки измерений или отсутствуие измерений
# - удалили из выборок строки с нулевыми параметрами
#
# Подготовили данные для обучения моделей:
# - разбили данные на таблицы с целевыми признаками и признаками для обучения
# - отмасштабировали данные содержащие признаки
#
# Написали функции для вычисления метрики моделей sMAPE и итоговой sMAPE.
#
# Создали несколько моделей для обучения:
# - RandomForestRegressor - Случайный лес
# - DecisionTreeRegressor - Дерево решений
# - LinearRegression - Линейная регрессия
# - CatBoostRegressor - Катбуст
#
# и подобрали для них оптимальные гиперпараметры.
#
# Выбрали модели с наилучшим значением sMAPE.<br>
#
# Для каждого из признаков оказалась лучшей модель **CatBoostRegressor**, но с разными параметрами:
# - для rougher - на обучающей выборке **sMAPE = 5.94**, на тестовой выборке **sMAPE = 3.84**
# - для final -  на обучающей выборке **sMAPE = 8.53**, на тестовой выборке **sMAPE = 7.3**
# - на тестовой выборке **итоговый sMAPE = 6.43**
#
#
# Оценили качество модели на Фиктивном регрессоре - DummyRegressor.<br>
# Модели на фиктивном регрессоре DummyRegressor со стратегией "среднее" и "медиана" показали одинаковые значения Итогового **sMAPE = 7.48** <br>
#
# Созданные нами модели предсказывают с меньшим sMAPE = **6.43**, чем фиктивный регрессор (среднее/медиана).<br>
# Можно сделать вывод, что полученные модели - адекватны.
